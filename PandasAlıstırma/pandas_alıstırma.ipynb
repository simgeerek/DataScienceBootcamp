# %%
import pandas as pd

# %%
#Question 1: From given data set print first and last five rows

# %%
df = pd.read_csv("Automobile_data.csv")

# %%
df.head() #first
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail() #last
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
#Question 2: Clean data and update the CSV file
#Replace all column values which contain ‘?’ and n.a with NaN.

# %%
df = pd.read_csv("Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
#Question 3: Find the most expensive car company name

# %%
df[["company","price"]][df.price == df["price"].max()]
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
#Question 4: Print All Toyota Cars details

# %%
df[df.company == "toyota"]
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %%
#Question 5: Count total cars per company

# %%
df["company"].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# volkswagen       4
# mitsubishi       4
# mercedes-benz    4
# audi             4
# porsche          3
# honda            3
# jaguar           3
# alfa-romero      3
# isuzu            3
# chevrolet        3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %%
#Question 6: Find each company’s Higesht price car

# %%
df.groupby("company").agg({"price":"max"})
# Out:
#                  price
# company
# alfa-romero    16500.0
# audi           18920.0
# bmw            41315.0
# chevrolet       6575.0
# dodge           6377.0
# honda          12945.0
# isuzu           6785.0
# jaguar         36000.0
# mazda          18344.0
# mercedes-benz  45400.0
# mitsubishi      8189.0
# nissan         13499.0
# porsche        37028.0
# toyota         15750.0
# volkswagen      9995.0
# volvo          13415.0

# %%
#Question 7: Find the average mileage of each car making company

# %%
df.groupby("company").agg({"average-mileage":"mean"})
# Out:
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %%
#Question 8: Sort all cars by Price column

# %%
df.sort_values("price", ascending=False)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
# ..    ...            ...          ...         ...     ...         ...
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 22     31          isuzu        sedan        94.5   155.9         ohc
# 23     32          isuzu        sedan        94.5   155.9         ohc
# 47     63        porsche    hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# ...

# %%
#Question 9: Concatenate two data frames using the following conditions
#Create two data frames using the following two Dicts, Concatenate those two data frames and create a key for each data frame.

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
gdf = pd.DataFrame(GermanCars)

# %%
gdf
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
jdf = pd.DataFrame(japaneseCars)

# %%
jdf
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
carsdf = pd.concat([gdf, jdf], keys=["Germany", "Japan"])
carsdf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %%
#Question 10: Merge two data frames using the following condition
#Create two data frames using the following two Dicts, Merge two data frames, and append the second data frame as a new column to the first data frame.

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
pricedf = pd.DataFrame(Car_Price)

# %%
pricedf
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
horsepowerdf = pd.DataFrame(car_Horsepower)

# %%
horsepowerdf
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
carsDf = pd.merge(pricedf, horsepowerdf, on="Company")

# %%
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %% [markdown]
# ### 1-Kütüphanelerin Yüklenmesi

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Setinin Yüklenmesi

# %%
#Veri seti -> Information on population, region, area size, infant mortality and more.
data = pd.read_csv("countries of the world.csv")

# %%
df = data.copy()

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# ### Sutun isimlerinin Değiştirilmesi

# %%
df.rename(columns = {"Country":"Ülke"})
# Out:
#                 Ülke                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
columns = ["Ülke","Bölge","Nüfus","Yüzölçümü","Nüfus_Yoğunluğu","Sahil_Şeridi","Göç_Durumu","Bebek_Ölüm_Oranı","Kişi_Başı_Gelir","Okuryazarlık",
          "Telefon_Oranı","Ekilebilir_Alan","Ekin","Diğer_Bitkiler","iklim","Doğum_Oranı","Ölüm_Oranı","Tarım","Sanayi","Memuriyet"]

# %%
for i in range(len(df.columns)):
    df.rename(columns={df.columns[i]:columns[i]}, inplace = True)

# %%
df.head()
# Out:
#               Ülke                                Bölge     Nüfus  Yüzölçümü  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)           31056997     647500
# 1         Albania   EASTERN EUROPE                        3581655      28748
# 2         Algeria   NORTHERN AFRICA                      32930091    2381740
# 3  American Samoa   OCEANIA                                 57794        199
# 4         Andorra   WESTERN EUROPE                          71201        468
#
#   Nüfus_Yoğunluğu Sahil_Şeridi Göç_Durumu Bebek_Ölüm_Oranı  Kişi_Başı_Gelir  \
# 0            48,0         0,00      23,06           163,07            700.0
# 1           124,6         1,26      -4,93            21,52           4500.0
# 2            13,8         0,04      -0,39               31           6000.0
# 3           290,4        58,29     -20,71             9,27           8000.0
# 4           152,1         0,00        6,6             4,05          19000.0
#
# ...

# %% [markdown]
# ### Veri Setinin Özellikleri

# %%
df.shape #20 sutun(columns) 227 satır(rows)
# Out:
# (227, 20)

# %%
df.isna().sum() #hangi sutunda kaç null value olduğunu görmek için
# Out:
# Ülke                 0
# Bölge                0
# Nüfus                0
# Yüzölçümü            0
# Nüfus_Yoğunluğu      0
# Sahil_Şeridi         0
# Göç_Durumu           3
# Bebek_Ölüm_Oranı     3
# Kişi_Başı_Gelir      1
# Okuryazarlık        18
# Telefon_Oranı        4
# Ekilebilir_Alan      2
# Ekin                 2
# Diğer_Bitkiler       2
# iklim               22
# Doğum_Oranı          3
# Ölüm_Oranı           4
# Tarım               15
# Sanayi              16
# Memuriyet           15
# dtype: int64

# %%
df.info() #hangi sutunun kaç dolu değeri olduğunu ve veri tipini gösteriyor
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Ülke                227 non-null object
# Bölge               227 non-null object
# Nüfus               227 non-null int64
# Yüzölçümü           227 non-null int64
# Nüfus_Yoğunluğu     227 non-null object
# Sahil_Şeridi        227 non-null object
# Göç_Durumu          224 non-null object
# Bebek_Ölüm_Oranı    224 non-null object
# Kişi_Başı_Gelir     226 non-null float64
# Okuryazarlık        209 non-null object
# Telefon_Oranı       223 non-null object
# Ekilebilir_Alan     225 non-null object
# Ekin                225 non-null object
# Diğer_Bitkiler      225 non-null object
# iklim               205 non-null object
# Doğum_Oranı         224 non-null object
# Ölüm_Oranı          223 non-null object
# Tarım               212 non-null object
# Sanayi              211 non-null object
# Memuriyet           212 non-null object
# dtypes: float64(1), int64(2), object(17)
# ...

# %%
nan_columns = df.columns[df.isna().any()].tolist() #null value olan sutunları almak için

# %%
nan_columns
# Out:
# ['Göç_Durumu',
#  'Bebek_Ölüm_Oranı',
#  'Kişi_Başı_Gelir',
#  'Okuryazarlık',
#  'Telefon_Oranı',
#  'Ekilebilir_Alan',
#  'Ekin',
#  'Diğer_Bitkiler',
#  'iklim',
#  'Doğum_Oranı',
#  'Ölüm_Oranı',
#  'Tarım',
#  'Sanayi',
#  'Memuriyet']

# %%
df.nunique() #kaçtane tekrar et
# Out:
# Ülke                227
# Bölge                11
# Nüfus               227
# Yüzölçümü           226
# Nüfus_Yoğunluğu     219
# Sahil_Şeridi        151
# Göç_Durumu          157
# Bebek_Ölüm_Oranı    220
# Kişi_Başı_Gelir     130
# Okuryazarlık        140
# Telefon_Oranı       214
# Ekilebilir_Alan     203
# Ekin                162
# Diğer_Bitkiler      209
# iklim                 6
# Doğum_Oranı         220
# Ölüm_Oranı          201
# Tarım               150
# Sanayi              155
# Memuriyet           167
# dtype: int64

# %% [markdown]
# ### Sutunlara göre verilerin düzenlenmesi

# %%
df['Bölge'].nunique()
# Out:
# 11

# %%
df['Bölge'].unique() #Sağ tarafta boşluklar var
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            '], dtype=object)

# %%
bölge = list(df.Bölge)

# %%
bölge[0:5]
# Out:
# ['ASIA (EX. NEAR EAST)         ',
#  'EASTERN EUROPE                     ',
#  'NORTHERN AFRICA                    ',
#  'OCEANIA                            ',
#  'WESTERN EUROPE                     ']

# %%
for i in range(len(bölge)):
    bölge[i] = bölge[i].strip() #sağ ve sol taraftaki boşlukları siliyoruz
bölge[0:5]
# Out:
# ['ASIA (EX. NEAR EAST)',
#  'EASTERN EUROPE',
#  'NORTHERN AFRICA',
#  'OCEANIA',
#  'WESTERN EUROPE']

# %%
df['Bölge'] = bölge #dataframe atadık düzeltilen verileri

# %%
df.Ülke.unique()
# Out:
# array(['Afghanistan ', 'Albania ', 'Algeria ', 'American Samoa ',
#        'Andorra ', 'Angola ', 'Anguilla ', 'Antigua & Barbuda ',
#        'Argentina ', 'Armenia ', 'Aruba ', 'Australia ', 'Austria ',
#        'Azerbaijan ', 'Bahamas, The ', 'Bahrain ', 'Bangladesh ',
#        'Barbados ', 'Belarus ', 'Belgium ', 'Belize ', 'Benin ',
#        'Bermuda ', 'Bhutan ', 'Bolivia ', 'Bosnia & Herzegovina ',
#        'Botswana ', 'Brazil ', 'British Virgin Is. ', 'Brunei ',
#        'Bulgaria ', 'Burkina Faso ', 'Burma ', 'Burundi ', 'Cambodia ',
#        'Cameroon ', 'Canada ', 'Cape Verde ', 'Cayman Islands ',
#        'Central African Rep. ', 'Chad ', 'Chile ', 'China ', 'Colombia ',
#        'Comoros ', 'Congo, Dem. Rep. ', 'Congo, Repub. of the ',
#        'Cook Islands ', 'Costa Rica ', "Cote d'Ivoire ", 'Croatia ',
#        'Cuba ', 'Cyprus ', 'Czech Republic ', 'Denmark ', 'Djibouti ',
#        'Dominica ', 'Dominican Republic ', 'East Timor ', 'Ecuador ',
# ...

# %%
df.Ülke = df["Ülke"].apply(lambda x : x.strip())

# %%
df.Ülke.unique()[0:5]
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra'],
#       dtype=object)

# %%
#Ülke ve Bölge harici columns değerleri sayısal değerler  bunları float a çevirmek istiyoruz
for i in df.columns:
    df[i] = df[i].apply(lambda x: str(x).replace(",",".")) #stringe çevirdik nokta ve virgül kullanılmış olabilir tek bir şekilde yazdırdık(noktalı)
    if(i != "Ülke")  and (i != "Bölge"):
        df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Ülke                227 non-null object
# Bölge               227 non-null object
# Nüfus               227 non-null float64
# Yüzölçümü           227 non-null float64
# Nüfus_Yoğunluğu     227 non-null float64
# Sahil_Şeridi        227 non-null float64
# Göç_Durumu          224 non-null float64
# Bebek_Ölüm_Oranı    224 non-null float64
# Kişi_Başı_Gelir     226 non-null float64
# Okuryazarlık        209 non-null float64
# Telefon_Oranı       223 non-null float64
# Ekilebilir_Alan     225 non-null float64
# Ekin                225 non-null float64
# Diğer_Bitkiler      225 non-null float64
# iklim               205 non-null float64
# Doğum_Oranı         224 non-null float64
# Ölüm_Oranı          223 non-null float64
# Tarım               212 non-null float64
# Sanayi              211 non-null float64
# Memuriyet           212 non-null float64
# ...

# %% [markdown]
# ### Verilerin Boş Kısımlarının Doldurulması

# %%
df.isna().sum()
# Out:
# Ülke                 0
# Bölge                0
# Nüfus                0
# Yüzölçümü            0
# Nüfus_Yoğunluğu      0
# Sahil_Şeridi         0
# Göç_Durumu           3
# Bebek_Ölüm_Oranı     3
# Kişi_Başı_Gelir      1
# Okuryazarlık        18
# Telefon_Oranı        4
# Ekilebilir_Alan      2
# Ekin                 2
# Diğer_Bitkiler       2
# iklim               22
# Doğum_Oranı          3
# Ölüm_Oranı           4
# Tarım               15
# Sanayi              16
# Memuriyet           15
# dtype: int64

# %%
df.loc[4,"iklim"]
# Out:
# 3.0

# %%
df.loc[[0,1,2,3],["iklim","Bölge","Ülke"]]
# Out:
#    iklim                 Bölge            Ülke
# 0    1.0  ASIA (EX. NEAR EAST)     Afghanistan
# 1    3.0        EASTERN EUROPE         Albania
# 2    1.0       NORTHERN AFRICA         Algeria
# 3    2.0               OCEANIA  American Samoa

# %%
#İklimin boş olduğu ülkeler
df[df["iklim"].isnull() == True]
# Out:
#                      Ülke                 Bölge        Nüfus   Yüzölçümü  \
# 5                  Angola    SUB-SAHARAN AFRICA   12127071.0   1246700.0
# 36                 Canada      NORTHERN AMERICA   33098932.0   9984670.0
# 50                Croatia        EASTERN EUROPE    4494749.0     56542.0
# 66          Faroe Islands        WESTERN EUROPE      47246.0      1399.0
# 78              Gibraltar        WESTERN EUROPE      27928.0         7.0
# 101                 Italy        WESTERN EUROPE   58133509.0    301230.0
# 115               Lebanon             NEAR EAST    3874050.0     10400.0
# 118                 Libya       NORTHERN AFRICA    5900754.0   1759540.0
# 120             Lithuania               BALTICS    3585906.0     65200.0
# 121            Luxembourg        WESTERN EUROPE     474413.0      2586.0
# 129                 Malta        WESTERN EUROPE     400214.0       316.0
# 137               Moldova   C.W. OF IND. STATES    4466706.0     33843.0
# ...

# %%
df[df["iklim"].isnull() == True].index
# Out:
# Int64Index([  5,  36,  50,  66,  78, 101, 115, 118, 120, 121, 129, 137, 138,
#             141, 145, 169, 171, 174, 177, 181, 186, 200],
#            dtype='int64')

# %%
len(df[df["iklim"].isnull() == True].index)
# Out:
# 22

# %%
df[df["Bölge"] == "WESTERN EUROPE"]["iklim"].isnull()
# Out:
# 4      False
# 12     False
# 19     False
# 54     False
# 66      True
# 68     False
# 69     False
# 76     False
# 78      True
# 79     False
# 85     False
# 93     False
# 98     False
# 99     False
# 101     True
# 104    False
# 119    False
# 121     True
# 129     True
# 138     True
# 146    False
# 154    False
# 164    False
# 177     True
# 190    False
# 195    False
# 196    False
# 213    False
# Name: iklim, dtype: bool

# %%
# WESTERN EUROPE bölgesinde bulunan iklim değeri boş olan ülkelerin indexi
(df[df["Bölge"] == "WESTERN EUROPE"]).loc[(df[df["Bölge"]=="WESTERN EUROPE"])["iklim"].isnull(),"iklim"].index
# Out:
# Int64Index([66, 78, 101, 121, 129, 138, 177], dtype='int64')

# %%
nan_columns
# Out:
# ['Göç_Durumu',
#  'Bebek_Ölüm_Oranı',
#  'Kişi_Başı_Gelir',
#  'Okuryazarlık',
#  'Telefon_Oranı',
#  'Ekilebilir_Alan',
#  'Ekin',
#  'Diğer_Bitkiler',
#  'iklim',
#  'Doğum_Oranı',
#  'Ölüm_Oranı',
#  'Tarım',
#  'Sanayi',
#  'Memuriyet']

# %%
bölgeler = list(df["Bölge"].unique())

# %%
bölgeler
# Out:
# ['ASIA (EX. NEAR EAST)',
#  'EASTERN EUROPE',
#  'NORTHERN AFRICA',
#  'OCEANIA',
#  'WESTERN EUROPE',
#  'SUB-SAHARAN AFRICA',
#  'LATIN AMER. & CARIB',
#  'C.W. OF IND. STATES',
#  'NEAR EAST',
#  'NORTHERN AMERICA',
#  'BALTICS']

# %%
#Bölgeleri kullanarak boş olan değerleri medianları alınarak dolduruyoruz
for i in bölgeler:
    for j in nan_columns:
        index = (df[df["Bölge"] == i]).loc[(df[df["Bölge"]==i])[j].isnull(),j].index
        if j=="iklim":
            for k in index:
                df.loc[k,j] = (df[df["Bölge"]==i][j].median())
        else:
            for k in index:
                df.loc[k,j] = round((df[df["Bölge"]==i][j].mean()),2)

# %%
df.isna().sum()
# Out:
# Ülke                0
# Bölge               0
# Nüfus               0
# Yüzölçümü           0
# Nüfus_Yoğunluğu     0
# Sahil_Şeridi        0
# Göç_Durumu          0
# Bebek_Ölüm_Oranı    0
# Kişi_Başı_Gelir     0
# Okuryazarlık        0
# Telefon_Oranı       0
# Ekilebilir_Alan     0
# Ekin                0
# Diğer_Bitkiler      0
# iklim               0
# Doğum_Oranı         0
# Ölüm_Oranı          0
# Tarım               0
# Sanayi              0
# Memuriyet           0
# dtype: int64

# %% [markdown]
# ### Sorular
#
# 1- Nüfus Yoğunluğu En Fazla Olan Ülkenin Adı
#
# 2- Ekilebilir Alanı En Yüksek Olan Ülkenin Adı ve Kişi Başı Gelirini Yazdırın
#
# 3- En Çok Ülke Bulunan Bölge Neresidir?
#
# 4- Ortalama Nüfus Yoğunluğu En Fazla Olan Bölgede En Düşük Yoğunluğa Sahip Ülkenin İsmi
#
# 5- Bölgelerin Genel Özelliklerini Anlatacak Bir DataFrame Oluşturalım ve Bundan Yeni Bir CSV Dosyası Yaratalım

# %% [markdown]
# ### 1.Soru

# %%
df.head()
# Out:
#              Ülke                 Bölge       Nüfus  Yüzölçümü  \
# 0     Afghanistan  ASIA (EX. NEAR EAST)  31056997.0   647500.0
# 1         Albania        EASTERN EUROPE   3581655.0    28748.0
# 2         Algeria       NORTHERN AFRICA  32930091.0  2381740.0
# 3  American Samoa               OCEANIA     57794.0      199.0
# 4         Andorra        WESTERN EUROPE     71201.0      468.0
#
#    Nüfus_Yoğunluğu  Sahil_Şeridi  Göç_Durumu  Bebek_Ölüm_Oranı  \
# 0             48.0          0.00       23.06            163.07
# 1            124.6          1.26       -4.93             21.52
# 2             13.8          0.04       -0.39             31.00
# 3            290.4         58.29      -20.71              9.27
# 4            152.1          0.00        6.60              4.05
#
#    Kişi_Başı_Gelir  Okuryazarlık  Telefon_Oranı  Ekilebilir_Alan   Ekin  \
# 0            700.0          36.0            3.2            12.13   0.22
# ...

# %%
df["Nüfus_Yoğunluğu"].max()
# Out:
# 16271.5

# %%
df[df["Nüfus_Yoğunluğu"] == df["Nüfus_Yoğunluğu"].max()]
# Out:
#        Ülke           Bölge    Nüfus  Yüzölçümü  Nüfus_Yoğunluğu  \
# 138  Monaco  WESTERN EUROPE  32543.0        2.0          16271.5
#
#      Sahil_Şeridi  Göç_Durumu  Bebek_Ölüm_Oranı  Kişi_Başı_Gelir  \
# 138         205.0        7.75              5.43          27000.0
#
#      Okuryazarlık  Telefon_Oranı  Ekilebilir_Alan  Ekin  Diğer_Bitkiler  \
# 138          99.0         1035.6              0.0   0.0           100.0
#
#      iklim  Doğum_Oranı  Ölüm_Oranı  Tarım  Sanayi  Memuriyet
# 138    3.0         9.19       12.91   0.17    0.25       0.71

# %%
df[df["Nüfus_Yoğunluğu"] == df["Nüfus_Yoğunluğu"].max()]["Ülke"]
# Out:
# 138    Monaco
# Name: Ülke, dtype: object

# %%
df[df["Nüfus_Yoğunluğu"] == df["Nüfus_Yoğunluğu"].max()]["Ülke"].values[0]
# Out:
# 'Monaco'

# %% [markdown]
# ### 2.Soru

# %%
df[df["Ekilebilir_Alan"] == df["Ekilebilir_Alan"].max()]["Ülke"].values[0]
# Out:
# 'Bangladesh'

# %%
df[df["Ekilebilir_Alan"] == df["Ekilebilir_Alan"].max()]["Kişi_Başı_Gelir"].values[0]
# Out:
# 1900.0

# %%
print("{0} ekilebilir alanı en yüksek olan ülkedir ve bu ülkede kişi başı gelir {1} dır.".format(df[df["Ekilebilir_Alan"] == df["Ekilebilir_Alan"].max()]["Ülke"].values[0],
                                                                                              df[df["Ekilebilir_Alan"] == df["Ekilebilir_Alan"].max()]["Kişi_Başı_Gelir"].values[0]))
# Out:
# Bangladesh ekilebilir alanı en yüksek olan ülkedir ve bu ülkede kişi başı gelir 1900.0 dır.

# %% [markdown]
# ### 3.Soru

# %%
df.groupby("Bölge").count()
# Out:
#                       Ülke  Nüfus  Yüzölçümü  Nüfus_Yoğunluğu  Sahil_Şeridi  \
# Bölge
# ASIA (EX. NEAR EAST)    28     28         28               28            28
# BALTICS                  3      3          3                3             3
# C.W. OF IND. STATES     12     12         12               12            12
# EASTERN EUROPE          12     12         12               12            12
# LATIN AMER. & CARIB     45     45         45               45            45
# NEAR EAST               16     16         16               16            16
# NORTHERN AFRICA          6      6          6                6             6
# NORTHERN AMERICA         5      5          5                5             5
# OCEANIA                 21     21         21               21            21
# SUB-SAHARAN AFRICA      51     51         51               51            51
# WESTERN EUROPE          28     28         28               28            28
#
# ...

# %%
df.groupby("Bölge").count()["Ülke"].max()
# Out:
# 51

# %%
(df.groupby("Bölge").count())["Ülke"] == df.groupby("Bölge").count()["Ülke"].max()
# Out:
# Bölge
# ASIA (EX. NEAR EAST)    False
# BALTICS                 False
# C.W. OF IND. STATES     False
# EASTERN EUROPE          False
# LATIN AMER. & CARIB     False
# NEAR EAST               False
# NORTHERN AFRICA         False
# NORTHERN AMERICA        False
# OCEANIA                 False
# SUB-SAHARAN AFRICA       True
# WESTERN EUROPE          False
# Name: Ülke, dtype: bool

# %%
df.groupby("Bölge").count()[(df.groupby("Bölge").count())["Ülke"] == df.groupby("Bölge").count()["Ülke"].max()].index[0]
# Out:
# 'SUB-SAHARAN AFRICA'

# %% [markdown]
# ### 4.Soru

# %%
df.groupby("Bölge").mean()
# Out:
#                              Nüfus     Yüzölçümü  Nüfus_Yoğunluğu  \
# Bölge
# ASIA (EX. NEAR EAST)  1.317137e+08  8.248826e+05      1264.825000
# BALTICS               2.394991e+06  5.833833e+04        39.833333
# C.W. OF IND. STATES   2.334013e+07  1.841737e+06        56.708333
# EASTERN EUROPE        9.992893e+06  9.601850e+04       100.900000
# LATIN AMER. & CARIB   1.248499e+07  4.565352e+05       136.202222
# NEAR EAST             1.219177e+07  2.722241e+05       427.081250
# NORTHERN AFRICA       2.690119e+07  1.003148e+06        38.933333
# NORTHERN AMERICA      6.633446e+07  4.356494e+06       260.860000
# OCEANIA               1.577698e+06  4.057053e+05       131.180952
# SUB-SAHARAN AFRICA    1.469484e+07  4.772825e+05        92.264706
# WESTERN EUROPE        1.415500e+07  1.325171e+05       952.042857
#
#                       Sahil_Şeridi  Göç_Durumu  Bebek_Ölüm_Oranı  \
# Bölge
# ASIA (EX. NEAR EAST)     17.926786    1.372500         41.780000
# ...

# %%
(df.groupby("Bölge").mean())["Nüfus_Yoğunluğu"].max()
# Out:
# 1264.825

# %%
(df.groupby("Bölge").mean())["Nüfus_Yoğunluğu"] == (df.groupby("Bölge").mean())["Nüfus_Yoğunluğu"].max()
# Out:
# Bölge
# ASIA (EX. NEAR EAST)     True
# BALTICS                 False
# C.W. OF IND. STATES     False
# EASTERN EUROPE          False
# LATIN AMER. & CARIB     False
# NEAR EAST               False
# NORTHERN AFRICA         False
# NORTHERN AMERICA        False
# OCEANIA                 False
# SUB-SAHARAN AFRICA      False
# WESTERN EUROPE          False
# Name: Nüfus_Yoğunluğu, dtype: bool

# %%
a=df.groupby("Bölge").mean()[(df.groupby("Bölge").mean())["Nüfus_Yoğunluğu"] == (df.groupby("Bölge").mean())["Nüfus_Yoğunluğu"].max()].index[0]
a
# Out:
# 'ASIA (EX. NEAR EAST)'

# %%
df[df["Bölge"]==a]["Nüfus_Yoğunluğu"].min()
# Out:
# 1.8

# %%
df[df["Bölge"]==a][df[df["Bölge"]==a]["Nüfus_Yoğunluğu"] == df[df["Bölge"]==a]["Nüfus_Yoğunluğu"].min()]["Ülke"].values[0]
# Out:
# 'Mongolia'

# %% [markdown]
# ### 5.Soru

# %%
ortalama = pd.DataFrame(index = df.Bölge.unique())

# %%
ortalama
# Out:
# Empty DataFrame
# Columns: []
# Index: [ASIA (EX. NEAR EAST), EASTERN EUROPE, NORTHERN AFRICA, OCEANIA, WESTERN EUROPE, SUB-SAHARAN AFRICA, LATIN AMER. & CARIB, C.W. OF IND. STATES, NEAR EAST, NORTHERN AMERICA, BALTICS]

# %%
df.columns
# Out:
# Index(['Ülke', 'Bölge', 'Nüfus', 'Yüzölçümü', 'Nüfus_Yoğunluğu',
#        'Sahil_Şeridi', 'Göç_Durumu', 'Bebek_Ölüm_Oranı', 'Kişi_Başı_Gelir',
#        'Okuryazarlık', 'Telefon_Oranı', 'Ekilebilir_Alan', 'Ekin',
#        'Diğer_Bitkiler', 'iklim', 'Doğum_Oranı', 'Ölüm_Oranı', 'Tarım',
#        'Sanayi', 'Memuriyet'],
#       dtype='object')

# %%
bölgeler = list(df.Bölge.unique())
for i in df.columns:
    if i == "Ülke":
        liste = []
        for j in bölgeler:
            x=df[df["Bölge"]==j]
            liste.append(len(x))
        ortalama["Ülke_Sayısı"] = liste
    elif i == "Bölge":
        pass
    else:
        liste=[]
        for j in bölgeler:
            x=df[df["Bölge"]==j]
            y=round(df[df["Bölge"] == j][i].mean(),2)
            liste.append(y)
        ortalama[i]=liste

# %%
ortalama
# Out:
#                       Ülke_Sayısı         Nüfus   Yüzölçümü  Nüfus_Yoğunluğu  \
# ASIA (EX. NEAR EAST)           28  1.317137e+08   824882.57          1264.83
# EASTERN EUROPE                 12  9.992893e+06    96018.50           100.90
# NORTHERN AFRICA                 6  2.690119e+07  1003148.33            38.93
# OCEANIA                        21  1.577698e+06   405705.33           131.18
# WESTERN EUROPE                 28  1.415500e+07   132517.07           952.04
# SUB-SAHARAN AFRICA             51  1.469484e+07   477282.47            92.26
# LATIN AMER. & CARIB            45  1.248499e+07   456535.20           136.20
# C.W. OF IND. STATES            12  2.334013e+07  1841736.92            56.71
# NEAR EAST                      16  1.219177e+07   272224.12           427.08
# NORTHERN AMERICA                5  6.633446e+07  4356494.20           260.86
# BALTICS                         3  2.394991e+06    58338.33            39.83
#
# ...

# %%
ortalama.to_csv("Bölgeler.csv")
